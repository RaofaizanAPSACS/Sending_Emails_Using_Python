# %%
import smtplib
from string import Template
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import pandas as pd
import numpy as np

# %%
MY_ADDRESS = 'example@nu.edu.pk'
PASSWORD = 'examplepassword'

# %%
def get_contacts(filename):
    """
    Return two lists names, emails containing names and email addresses
    read from a file specified by filename.
    """
    
    names = []
    emails = []
    df = pd.read_csv(filename)
    df = df[df["Position"].isin(["Member"])]
    names = df["Student Name"]
    emails = df["email"] 
    position = df["Position"]  
    return names, emails, position

# %%
n, e, p = get_contacts("Data_Science_team.csv")
pd.DataFrame({"Name":n, "Emails":e, "Position":p})
# Out:
#                     Name             Emails Position
# 0      Ayesha Ahmed baig  k200172@nu.edu.pk   Member
# 1           Kanza Batool  k200423@nu.edu.pk   Member
# 2        Syed M. Huzaifa  k214948@nu.edu.pk   Member
# 3            Bilal Ahmed  k224836@nu.edu.pk   Member
# 4           Ruhan Ahmed   k224812@nu.edu.pk   Member
# 5           Talha Shahid  k213355@nu.edu.pk   Member
# 6          M.Hamza Imran  k224757@nu.edu.pk   Member
# 7                M.Musab  k200226@nu.edu.pk   Member
# 8            Rayyan Alam  k224373@nu.edu.pk   Member
# 9           Ali M. Nizar  k224469@nu.edu.pk   Member
# 10             M. Danish  k224381@nu.edu.pk   Member
# 11        M.Talha Shaikh  k214564@nu.edu.pk   Member
# 12             Areeb Ali  k201686@nu.edu.pk   Member
# 13          Farhan Ahmed  k214600@nu.edu.pk   Member
# 14           Aarib Azfar  k213342@nu.edu.pk   Member
# 15         Yousha Haider  k214672@nu.edu.pk   Member
# 16              Ali Zain  k213331@nu.edu.pk   Member
# ...

# %%
def read_template(filename):
    """
    Returns a Template object comprising the contents of the 
    file specified by filename.
    """
    
    with open(filename, 'r', encoding='utf-8') as template_file:
        template_file_content = template_file.read()
    return Template(template_file_content)

# %%
# set up the SMTP server
s = smtplib.SMTP(host='smtp.gmail.com', port=587)
s.ehlo()
s.starttls()
s.ehlo()
s.login(MY_ADDRESS, PASSWORD)
# Out:
# (235, b'2.7.0 Accepted')

# %% [markdown]
# ### Sending emails separately to multiple recipients using loop

# %%
def main():
    # read contacts
    # names, emails, position = get_contacts("Data_Science_team.csv") 
    names = ["Faizan", "Ashar"]
    emails = ["k200366@nu.edu.pk","k200364@nu.edu.pk"]
    position = ["Deputy", "Coordinator"]

    # For each contact, send the email:
    for name, email, pos in zip(names, emails, position):
        msg = MIMEMultipart()       # create a message
        message_template = read_template('message.txt')
        # add in the actual person name to the message template
        message = message_template.substitute({"PERSON_NAME":name.title()})

        # Prints out the message body for our sake
        print(message)
        print(email)

        # setup the parameters of the message
        msg['From']=MY_ADDRESS
        msg['To']= email
        msg["Cc"] = "k200364@nu.edu.pk, k201905@nu.edu.pk"
        msg['Subject']="GOOGLE DEVELOPER STUDENT CLUB INDUCTIONS RESULT"
        
        # add in the message body
        msg.attach(MIMEText(message, 'plain'))
        
        # send the message via the server set up earlier.
        s.send_message(msg)
        del msg
        
    # Terminate the SMTP session and close the connection
    s.quit()
    
if __name__ == '__main__':
    main()
# Out:
# Hi Ayesha Ahmed Baig,
#
# Congrats!
# You have been selected as a Member of the GDSC Data Science Team.
# Looking forward to your active response throughout the period.
#
# Thanks & Regards,
# Muhammad Faizan - Data Science Lead (GDSC)
# k200172@nu.edu.pk
# Hi Kanza Batool,
#
# Congrats!
# You have been selected as a Member of the GDSC Data Science Team.
# Looking forward to your active response throughout the period.
#
# Thanks & Regards,
# Muhammad Faizan - Data Science Lead (GDSC)
# k200423@nu.edu.pk
# Hi Syed M. Huzaifa,
#
# Congrats!
# You have been selected as a Member of the GDSC Data Science Team.
# Looking forward to your active response throughout the period.
#
# Thanks & Regards,
# Muhammad Faizan - Data Science Lead (GDSC)
# k214948@nu.edu.pk
# Hi Bilal Ahmed,
#
# Congrats!
# You have been selected as a Member of the GDSC Data Science Team.
# Looking forward to your active response throughout the period.
#
# Thanks & Regards,
# Muhammad Faizan - Data Science Lead (GDSC)
# ...

# %% [markdown]
# ### Sending same email to multiple recipients without loop

# %%
def main():
    # read contacts
    names, emails, position = get_contacts("Data_Science_team.csv")
    # emails = ["k200366@nu.edu.pk"]

    message = "<pre>Dear Students, <br>Please Join the whatsapp group: <ul> <li> <a href= https://chat.whatsapp.com/BU4Xzrgp70iECxvqJAHrBM >Join GDSC Data Science Team Group 22-23</a> </li> </ul> <br> Thanks & Regards, <br> Muhammad Faizan - Data Science Lead</pre>"
    msg = MIMEMultipart()       

    # setup the parameters of the message
    msg['From']=MY_ADDRESS
    msg['To']= ",".join(emails)
    msg["Cc"] = "k200364@nu.edu.pk, k201905@nu.edu.pk"
    msg['Subject']="Google DSC Data Science Whatsapp Group"
    
    # add in the message body
    msg.attach(MIMEText(message, 'html'))
    
    # send the message via the server set up earlier.
    s.send_message(msg)
        
    # Terminate the SMTP session and close the connection
    s.quit()
    
if __name__ == '__main__':
    main()
